# %%
#firstname camel naming case
#firstName pascal naming case 
#first_name snake naming case

# %%
number1 = 10

# %%
print(number1)
# Out:
# 10

# %%
print('hello world')
# Out:
# hello world

# %%
word1 = 'we\'re brothers from other side of town' #backward slash(\) denotes the escape character
print(word1)
# Out:
# we're brothers from other side of town

# %%
word = "we 're brothers from the other side of the town"
print(word1)
# Out:
# we're brothers from other side of town

# %%
word2 = "Hey python is fun,\nareyou not going to learn it,\nif so visit us at earlycode" #backward slash + N denotes new line
print (word2)
# Out:
# Hey python is fun,
# areyou not going to learn it,
# if so visit us at earlycode

# %%
word2 = """Hey python is fun,
reyou not going to learn it,
if so visit us at earlycode 
"""# """"""denotes new line
print (word2)
# Out:
# Hey python is fun,
# reyou not going to learn it,
# if so visit us at earlycode

# %%
course= "python class"
print("Hey welcome to", course)# joing of string and variable
# Out:
# Hey welcome to python class

# %%
print('hello'+' '+'world')# joing of string and string
# Out:
# hello world

# %%
firstname="Joel"
secondname="Sanni"
print(firstname, secondname)#joining of variable and variable
# Out:
# Joel Sanni

# %%
priceone =25000
pricetwo = 75000
pricethree = 7000
Report = "base on todays activities, i sold 5 pairs of shirt for {},also sold a suite for {},and a shoe for {}"
print(Report.format(priceone,pricetwo,pricethree))#Inject a variable inside string which is called string formating
# Out:
# base on todays activities, i sold 5 pairs of shirt for 25000,also sold a suite for 75000,and a shoe for 7000

# %%
print(f"base on todays activities, i sold 5 pairs of shirt for {priceone},also sold a suite for {pricetwo},and a shoe for {pricethree}")
# Out:
# base on todays activities, i sold 5 pairs of shirt for 25000,also sold a suite for 75000,and a shoe for 7000

# %%
word1 = "school"
word2 = "SCHOOL"
word3 = "python is fun"
word4 = "   info@gmail.com"

# %%
print(word1.upper())
# Out:
# SCHOOL

# %%
print(word2.lower())
# Out:
# school

# %%
print(word3.capitalize())
# Out:
# Python is fun

# %%
print(word3.title())
# Out:
# Python Is Fun

# %%
print(word3.split())
# Out:
# ['python', 'is', 'fun']

# %%
print(word4.strip())#strip clears off white space either at the begining of at the end
# Out:
# info@gmail.com

# %%
num1 = 10
num2 = 120.2
word = 'simeon'
num3 = '5'

# %%
num1 = 15
num2 = 5
print(num1+num2)
print(num1-num2)
print(num1/num2)
print(num1*num2)
print(num1%num2)
print(num1//num2)
print(num1**num2)Arithmatic operators
# Out:
# 20
# 10
# 3.0
# 75
# 0
# 3
# 759375

# %%
print(num1>num2)
# Out:
# True

# %%
print(num1<num2)
print(num1>=num2)
print(num1<=num2)
print(num1==num2)
print(num1!=num2)# comparisim oprators
# Out:
# False
# True
# False
# False
# True

# %%
print(num1>num2 and num1<num2)
print(num1>num2 or num1<num2)
print(not num1)#logical operators
# Out:
# False
# True
# False

# %%
word5 = 'python'
print('p'in word5)
# Out:
# True

# %%
print('p' not in word5) #membership opertator
# Out:
# False

# %%
print(num1 is num2)
print(num1 is not num2)#Ioperatordentity
# Out:
# False
# True

# %%
numbers = (2,5,2,8,9,2,6,2,9,8,9,2,3,6,5,2)

# %%
type(numbers)
# Out:
# tuple

# %%
len(numbers)
# Out:
# 16

# %%
numbers[3]
# Out:
# 8

# %%
numbers [3:10]
# Out:
# (8, 9, 2, 6, 2, 9, 8)

# %%
numbers [3:-6]
# Out:
# (8, 9, 2, 6, 2, 9, 8)

# %%
print(9 in numbers)
# Out:
# True

# %%
numbers.count(5)
# Out:
# 2

# %%
numbers.index(5)
# Out:
# 1

# %%
numbers.index(5,10,16)
# Out:
# 14

# %%
fruit = ['Orange','Apple','Mango','Cashew', 'Pawpaw']

# %%
fruit.append('Gwava')# Append function
print(fruit)
# Out:
# ['Orange', 'Apple', 'Mango', 'Cashew', 'Pawpaw', 'Gwava']

# %%
n_fruit = ('Orange','orange','orange','carrot','pineaple')
fruit.extend(n_fruit)
print(fruit) #Extend
# Out:
# ['Orange', 'Apple', 'Mango', 'Cashew', 'Pawpaw', 'Gwava', 'Orange', 'orange', 'orange', 'carrot', 'pineaple']

# %%
fruit.insert(1,'pawapaw')
print(fruit) #Insert
# Out:
# ['Orange', 'pawapaw', 'Apple', 'Mango', 'Cashew', 'Pawpaw', 'Gwava', 'Orange', 'orange', 'orange', 'carrot', 'pineaple']

# %%
fruit.sort()
print(fruit) #sort
# Out:
# ['Apple', 'Cashew', 'Gwava', 'Mango', 'Orange', 'Orange', 'Pawpaw', 'carrot', 'orange', 'orange', 'pawapaw', 'pineaple']

# %%
fruit.reverse()
print(fruit)
# Out:
# ['Apple', 'Cashew', 'Gwava', 'Mango', 'Orange', 'Orange', 'Pawpaw', 'carrot', 'orange', 'orange', 'pawapaw', 'pineaple']

# %%
fruit.pop()
print(fruit)
# Out:
# ['Apple', 'Cashew', 'Gwava', 'Mango', 'Orange', 'Orange', 'Pawpaw', 'carrot', 'orange', 'orange', 'pawapaw']

# %%
fruit.remove('Gwava')
print(fruit)
# Out:
# ['Apple', 'Cashew', 'Mango', 'Orange', 'Orange', 'Pawpaw', 'carrot', 'orange', 'orange', 'pawapaw']

# %%
D_fruit = fruit.copy()
print(D_fruit)
# Out:
# ['Apple', 'Cashew', 'Mango', 'Orange', 'Orange', 'Pawpaw', 'carrot', 'orange', 'orange', 'pawapaw']

# %%
D_fruit.clear()
print(D_fruit)
# Out:
# []

# %%
Del(D_fruit)
print(D_fruit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-f945ef8206a2> in <module>
# ----> 1 Del(D_fruit)
#       2 print(D_fruit)
#
# NameError: name 'Del' is not defined

# %%
records = {
    'Name':'Simeon',
    'Gender':'Male',
    'Age': 25
}

# %%
records['Gender']
# Out:
# 'Male'

# %%
records.keys()
# Out:
# dict_keys(['Name', 'Gender', 'Age'])

# %%
records.values()
# Out:
# dict_values(['Simeon', 'Male', 25])

# %%
records.items()
# Out:
# dict_items([('Name', 'Simeon'), ('Gender', 'Male'), ('Age', 25)])

# %% [markdown]
# # Conditional Stament

# %%
num = 10
if num <= 50:
    print('you are very correct')
# Out:
# you are very correct

# %%
num = 10
if num > 50:
    print('you are very correct')
else:
    print('operation is not correct')
# Out:
# operation is not correct

# %%
speed1 = 70
speed2 = int(input('Driver\'s speed:'))
if speed2 <= speed1:
    print('you are on track')
else:
    speed3 = (speed2 - speed1)// 5
    if speed3 <= 12:
        print(f'Hey are driving above the default speed bewarned and the extra point is {speed3}')
    else:
        print(f'Hey are driving above the default speed with an high extra point of {speed3}, you are hereby suspended')
# Out:
# Driver's speed:100
# Hey are driving above the default speed bewarned and the extra point is 6

# %%
num = int(input('Enter number:'))
if num == 0:
    print('Number is zero')
elif num < 0:
    print('Number is negative')
else:
    print('number is positive')
# Out:
# Enter number:-5
# Number is negative

# %%
print('WELCOME TO MADAMB\'S KITCHEN')
print('HOME OF DELICIOUS FOOD')
print('WE ARE ALWAYS AT YOUR SERVICE')
choice = int(input('please seat on any roll for desired meal to be served'))
if choice == 1:
    print('you will be served rice,plantain,beef or chicken, water and any drink of your choice')
elif choice == 2:
    print('you will be served pounded yam with any soup of your choice, beef or chicken or fish or cow head, water and any drink of your choice')
elif choice == 3:
    print('you will be served Amala with any soup of your choice, beef or chicken or fish or cow head, water and any drink of your choice')
elif choice == 4:
    print('you will be served any snacks of your choice,beef or chicken, water and any drink of your choice')
else:
    print('Invalid option')
# Out:
# WELCOME TO MADAMB'S KITCHEN
# HOME OF DELICIOUS FOOD
# WE ARE ALWAYS AT YOUR SERVICE
# please seat on any roll for desired meal to be served5
# Invalid option
