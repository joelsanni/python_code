# %%
def intro():
    print('WELCOME TO JOESAN KITCHEN')
def main():
    intro()
    tag = int(input('please select a tag'))
    if tag == 1:
        plate = int(input('number of plate:'))
        rice = int(input('numbers of spoons of rice:'))
        Salad = int(input('numbers of portions of salad:'))
        plantain = int(input('numbers of slice of plantain:'))
        chicken = int(input('numbers of parts of chicken:'))
        water = int(input('numbers of bottle water:'))
        drinks = int(input('numbers of bottle of drink:'))
        
        Rice_Total = rice * 600
        salad_Total = salad * 250
        plantain_Total = plantain * 200
        chicken_Total = Chicken * 1200
        water_Total = water * 100
        drinks_Total = drinks * 150
        
        Total_price_price = plates*(Rice_total + Salad_total + Plantain_total + Chicken_total + Water_total + Drinks_total)
        print(f'find above your order and the total price is {total_price}')
        print('Thanks for visiting Resturant')
        feedback = input('Give us a rating and feedback')
        
    elif tag == 2:
        plate = int(input('number of plate'))
        swallow_with_any_soup_of_your_choice = int(input('numbers of wraps of swallow'))
        Cow_head = int(input('portions of cow head:'))
        Beef = int(input('portion of Beef:'))
        chicken = int(input('portion of chicken'))
        goat_head = int(input('portion of goat head:'))
        water = int(input('numbers of bottle water:'))
        drinks = int(input('numbers of bottle of drink:'))
        
        swallow_total = swallow_with_any_soup_of_your_choice * 500
        cow_head_total = Cow_head * 250
        beef_total = Beef * 200
        chicken_total = chicken * 1200
        goat_head_total = goat_head * 700
        water_total = water * 100
        drinks_total = drinks * 150
        
        total_price = plate*(swallow_total + cow_head_total + beef_total + chicken_total + goat_head_total + water_total + drinks_total)
        print(f'find above your order and the total price is {total_price}')
        print('Thanks for visiting Resturant')
        feedback = input('Give us a rating and feedback')
        
    elif tag == 3:
        plate = int(input('numbers of plate:'))
        Meat_pie = int(input('pieces of meatpie:'))
        chicken_and_chip = int(input('portions of chicken_and_chip:'))
        cake = int(input('portion of cake:'))
        shawama = int(input('portion of shawama'))
        burger = int(input('portion of burgar:'))
        water = int(input('numbers of bottle water:'))
        drinks = int(input('numbers of bottle of drink:'))
        
        Meat_pie = Meat_pie * 500
        Chicken_and_chip = chicken_and_chip * 250
        Cake = cake * 200
        Shawama = shawama * 1500
        burar = burar * 700
        water_Total = water * 200
        drinks_Total = drinks * 300
        
        Total_price_price = plates*(Meatpie_total + Chicken_and_chip_Total + Cake_total + Shawama_total + Burger_total + Water_total + Drinks_total)
        print(f'find above your order and the total price is {total_price}')
        print('Thanks for visiting Resturant')
        feedback = input('Give us a rating and feedback')
    else:
        print('invalid tag')
main()
# Out:
# WELCOME TO JOESAN KITCHEN
# please select a tag2
# number of plate7
# numbers of wraps of swallow14
# portions of cow head:4
# portion of Beef:3
# portion of chicken0
# portion of goat head:7
# numbers of bottle water:7
# numbers of bottle of drink:7
# find above your order and the total price is 106750
# Thanks for visiting Resturant
# Give us a rating and feedbackservice rendered highly commendable
